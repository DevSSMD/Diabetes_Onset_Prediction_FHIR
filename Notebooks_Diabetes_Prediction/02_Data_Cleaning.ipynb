# %% [markdown]
# # Project: Predicting Diabetes Onset FHIR EHR Data
# ### Notebook: 02_Data_Cleaning.ipynb
# ### Purpose: Clean raw data

# %%
import pandas as pd
import numpy as np
from typing import List, Tuple
from pathlib import Path

# %%
# Helper function to load data
def load_data(file_names: List[str], path: str) -> List[pd.DataFrame]:
    dfs = []
    base_path = Path(path)
    
    for name in file_names:
        file_path = base_path / name

        try:
            df = pd.read_csv(file_path)
            dfs.append(df)
        except fileNotFoundError:
            print(f"[WARNING] File not found at: {file_path}")
        except pd.errors.EmptyDataError:
            print(f"[WARNING] File empty: {file_path}")
        except Exception as e:
            print(f"Failed to load data at {file_path}:{e}")
    return dfs

# %%
# Load data
file_names = ['Conditions_Raw.csv',
             'Patients_Raw.csv',
             'Encounters_Raw.csv',
             'Observations_Raw.csv']
base_path = '/Users/sanasiddiqui/Desktop/Current Desktop/Data Portfolio Projects/Diabetes_Onset_Prediction_FHIR/Data_Diabetes_Prediction/Raw'
dfs = load_data(file_names, path=base_path)

# %%
df_conditions_raw = dfs[0]
df_patients_raw = dfs[1]
df_encounters_raw = dfs[2]
df_observations_raw = dfs[3]

# %% [markdown]
# ## Preliminary Data Validation of Response Variable (Diabetes)

# %%
# check data frame shapes
print(
    f"Patients: {df_patients_raw.shape}\n" 
    f"Observations: {df_observations_raw.shape}\n" 
    f"Encounters: {df_encounters_raw.shape}\n" 
    f"Conditions: {df_conditions_raw.shape}")
# Out:
# Patients: (1159, 3)
# Observations: (585691, 6)
# Encounters: (66166, 5)
# Conditions: (41676, 7)

# %%
# Create a flag for prediabetic patients to do initial validation
# confirming if we have enough prediabetic and diabetic patients

df_conditions_raw["is_prediabetes"] = df_conditions_raw["name"].str.lower().str.contains("prediabetes")

# %%
# Create a flag for diabetic patients to do initial validation
# confirming if we have enough prediabetic and diabetic patients

df_conditions_raw["is_diabetes"] = df_conditions_raw["name"].str.lower().str.contains("diabetes")

# %%
# count prediabetic patients
n_prediabetic_pts = df_conditions_raw[df_conditions_raw["is_prediabetes"]]["patient_id"].nunique()
n_prediabetic_pts
# Out:
# 445

# %%
# count diabetic patients
n_diabetic_pts = df_conditions_raw[df_conditions_raw["is_diabetes"]]["patient_id"].nunique()
n_diabetic_pts
# Out:
# 503

# %%
# convert onset column into datetime object
df_conditions_raw['onset'] = pd.to_datetime(df_conditions_raw['onset'], errors='coerce')
# Out:
# /var/folders/jr/vyvz729175v013k_g7gzk_7c0000gn/T/ipykernel_68474/2443224953.py:2: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   df_conditions_raw['onset'] = pd.to_datetime(df_conditions_raw['onset'], errors='coerce')

# %%
# find all pre and diabetic patients,
# merge rows to find how many prediabetic pts converting to diabetic
pre = df_conditions_raw[df_conditions_raw['is_prediabetes']]
dm = df_conditions_raw[df_conditions_raw['is_diabetes']]

# merge
merged = pre.merge(
    dm,
    on='patient_id',
    suffixes=('_pre','_dm')
)

# %%
# find patients progressing from prediabetes to diabetes

progressors = merged[merged['onset_pre'] < merged['onset_dm']]
progressors.head()
# Out:
#                                        patient_id  \
# 5   urn:uuid:dbc13ff9-face-3a16-b7b2-0073d73dea9a
# 6   urn:uuid:dbc13ff9-face-3a16-b7b2-0073d73dea9a
# 7   urn:uuid:dbc13ff9-face-3a16-b7b2-0073d73dea9a
# 9   urn:uuid:3e5092da-7854-5cfe-2cfb-8f3c96e182fd
# 10  urn:uuid:3e5092da-7854-5cfe-2cfb-8f3c96e182fd
#
#                         condition_id_pre   code_pre               name_pre  \
# 5   dbc13ff9-face-3a16-3595-9b1b323e77e9  714628002  Prediabetes (finding)
# 6   dbc13ff9-face-3a16-3595-9b1b323e77e9  714628002  Prediabetes (finding)
# 7   dbc13ff9-face-3a16-3595-9b1b323e77e9  714628002  Prediabetes (finding)
# 9   3e5092da-7854-5cfe-4033-d2939757e402  714628002  Prediabetes (finding)
# 10  3e5092da-7854-5cfe-4033-d2939757e402  714628002  Prediabetes (finding)
#
#                     onset_pre          recorded_date_pre clinical_status_pre  \
# 5   1987-02-27T12:12:34-05:00  1987-02-27T12:12:34-05:00              active
# 6   1987-02-27T12:12:34-05:00  1987-02-27T12:12:34-05:00              active
# 7   1987-02-27T12:12:34-05:00  1987-02-27T12:12:34-05:00              active
# 9   1971-05-02T15:00:43-04:00  1971-05-02T15:00:43-04:00              active
# 10  1971-05-02T15:00:43-04:00  1971-05-02T15:00:43-04:00              active
#
#     is_prediabetes_pre  is_diabetes_pre                       condition_id_dm  \
# 5                 True             True  dbc13ff9-face-3a16-1429-2dce430cf0a7
# 6                 True             True  dbc13ff9-face-3a16-5bac-b481539326a1
# 7                 True             True  dbc13ff9-face-3a16-2bbd-5dbdc71ab9c4
# 9                 True             True  3e5092da-7854-5cfe-1df2-b3c726cc5f7d
# 10                True             True  3e5092da-7854-5cfe-54ff-f12667c85139
#
#             code_dm                                            name_dm  \
# 5         127013003  Disorder of kidney due to diabetes mellitus (d...
# 6    90781000119102  Microalbuminuria due to type 2 diabetes mellit...
# 7   157141000119108  Proteinuria due to type 2 diabetes mellitus (d...
# 9         127013003  Disorder of kidney due to diabetes mellitus (d...
# 10   90781000119102  Microalbuminuria due to type 2 diabetes mellit...
#
#                      onset_dm           recorded_date_dm clinical_status_dm  \
# 5   2015-03-27T13:12:34-04:00  2015-03-27T13:12:34-04:00             active
# 6   2018-04-13T13:12:34-04:00  2018-04-13T13:12:34-04:00             active
# 7   2019-01-04T12:12:34-05:00  2019-01-04T12:12:34-05:00             active
# 9   2008-04-06T15:00:43-04:00  2008-04-06T15:00:43-04:00             active
# 10  2011-07-03T15:00:43-04:00  2011-07-03T15:00:43-04:00             active
#
#     is_prediabetes_dm  is_diabetes_dm
# 5               False            True
# 6               False            True
# 7               False            True
# 9               False            True
# 10              False            True

# %%
progressors.shape
# Out:
# (263, 17)

# %% [markdown]
# ## Data Cleaning

# %%
# copy data to preserve raw data

df_patients = df_patients_raw.copy()
df_obs = df_observations_raw.copy()
df_enc = df_encounters_raw.copy()
df_cond = df_conditions_raw.copy()

# %% [markdown]
# #### Structural Checks

# %%
# Helper function to inspect dataframe structure

def inspect_structure(df, name: str, n: int = 5) -> None:
    """inspect structure, columns, data types, and first n rows
    of dataframe

    Parameters:
    df: dataframe
    name: name of dataframe
    n: number of first few rows in dataframe
    """
    print(f"\n=== {name} ===")
    print(f"\nShape: {df.shape}")
    print("\nColumns: ")
    print(list(df.columns))
    print("\nDtypes: ")
    print(df.dtypes)
    print(f"\nPreview (first {n} rows):")
    print(df.head(n))

# %%
# Wrapper function to check structure of multiple dataframes at once

def run_structural_checks(dfs: dict) -> None:
    for name, df in dfs.items():
        inspect_structure(df, name)

# %%
# dictionary holding all dataframes and their names

dfs = {
    "Patients": df_patients,
    "Observations": df_obs,
    "Encounters": df_enc,
    "Conditions": df_cond
}

# %%
# inspect all dataframe structures

run_structural_checks(dfs)
# Out:
# === Patients ===
#
# Shape: (1159, 3)
#
# Columns:
# ['patient_id', 'gender', 'birth_date']
#
# Dtypes:
# patient_id    object
# gender        object
# birth_date    object
# dtype: object
#
# Preview (first 5 rows):
#                              patient_id  gender  birth_date
# 0  a8a4c7d6-722a-a914-04b6-a23a7c3496e2  female  1999-05-21
# 1  779b82f4-c8cd-9764-2f80-28f0b176a418  female  2000-03-03
# 2  e696153b-4bda-a741-04fe-a1fd43f60fd9  female  1972-04-14
# 3  7e0366e0-5cf1-1f51-f609-3ec9c2197140  female  1998-03-26
# 4  f286e228-2d19-4405-da1c-23dcae75169b  female  1971-04-03
#
# === Observations ===
#
# Shape: (585691, 6)
#
# Columns:
# ['patient_id', 'code', 'name', 'value', 'unit', 'time']
#
# Dtypes:
# patient_id     object
# code           object
# name           object
# value         float64
# unit           object
# time           object
# dtype: object
#
# Preview (first 5 rows):
#                                       patient_id    code  \
# 0  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2  6206-7
# 1  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2  6273-7
# 2  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2  6082-2
# 3  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2  6246-3
# 4  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2  6276-0
#
#                                      name     value  unit  \
# 0   Peanut IgE Ab [Units/volume] in Serum  0.088943  kU/L
# 1   Walnut IgE Ab [Units/volume] in Serum  0.086704  kU/L
# 2  Codfish IgE Ab [Units/volume] in Serum  0.033234  kU/L
# 3   Shrimp IgE Ab [Units/volume] in Serum  0.298170  kU/L
# 4    Wheat IgE Ab [Units/volume] in Serum  0.151060  kU/L
#
#                         time
# 0  2016-06-26T10:58:45-04:00
# 1  2016-06-26T10:58:45-04:00
# 2  2016-06-26T10:58:45-04:00
# 3  2016-06-26T10:58:45-04:00
# 4  2016-06-26T10:58:45-04:00
#
# === Encounters ===
#
# Shape: (66166, 5)
#
# Columns:
# ['patient_id', 'encounter_id', 'start', 'end', 'class']
#
# Dtypes:
# patient_id      object
# encounter_id    object
# start           object
# end             object
# class           object
# dtype: object
#
# Preview (first 5 rows):
#                                       patient_id  \
# 0  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2
# 1  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2
# 2  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2
# 3  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2
# 4  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2
#
#                            encounter_id                      start  \
# 0  a8a4c7d6-722a-a914-08ad-b3487ef3841c  2002-07-05T05:10:07-04:00
# 1  a8a4c7d6-722a-a914-361b-7ce09b223ba3  2002-07-07T19:10:07-04:00
# 2  a8a4c7d6-722a-a914-336b-d22ae367ca4f  2012-05-25T05:10:07-04:00
# 3  a8a4c7d6-722a-a914-1914-d529e1eb8980  2013-02-15T04:10:07-05:00
# 4  a8a4c7d6-722a-a914-c010-05323bffc60e  2015-05-10T05:10:07-04:00
#
#                          end class
# 0  2002-07-05T05:25:07-04:00   AMB
# 1  2002-07-07T19:39:24-04:00   AMB
# 2  2012-05-25T05:31:15-04:00   AMB
# 3  2013-02-15T04:25:07-05:00   AMB
# 4  2015-05-10T05:25:07-04:00   AMB
#
# === Conditions ===
#
# Shape: (41676, 9)
#
# Columns:
# ['patient_id', 'condition_id', 'code', 'name', 'onset', 'recorded_date', 'clinical_status', 'is_prediabetes', 'is_diabetes']
#
# Dtypes:
# patient_id         object
# condition_id       object
# code                int64
# name               object
# onset              object
# recorded_date      object
# clinical_status    object
# is_prediabetes       bool
# is_diabetes          bool
# dtype: object
#
# Preview (first 5 rows):
#                                       patient_id  \
# 0  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2
# 1  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2
# 2  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2
# 3  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2
# 4  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2
#
#                            condition_id       code  \
# 0  a8a4c7d6-722a-a914-557d-67cc3166d819  367498001
# 1  a8a4c7d6-722a-a914-4b62-c14a12b6feb2  314529007
# 2  a8a4c7d6-722a-a914-3821-c283230cd572   72892002
# 3  a8a4c7d6-722a-a914-2448-0d44be79cfdc  224299000
# 4  a8a4c7d6-722a-a914-fbce-2c51d5add2eb  160903007
#
#                                     name                      onset  \
# 0  Seasonal allergic rhinitis (disorder)  2002-07-05T05:10:07-04:00
# 1      Medication review due (situation)  2013-02-15T04:10:07-05:00
# 2             Normal pregnancy (finding)  2016-10-07T05:10:07-04:00
# 3    Received higher education (finding)  2017-06-23T05:47:57-04:00
# 4         Full-time employment (finding)  2017-06-23T05:47:57-04:00
#
#                recorded_date clinical_status  is_prediabetes  is_diabetes
# 0  2002-07-05T05:10:07-04:00        resolved           False        False
# 1  2013-02-15T04:10:07-05:00        resolved           False        False
# 2  2016-10-07T05:10:07-04:00        resolved           False        False
# 3  2017-06-23T05:47:57-04:00          active           False        False
# 4  2017-06-23T05:47:57-04:00        resolved           False        False

# %%
# ensure no NA patient ids and all present in df_patients

assert df_obs['patient_id'].notna().all()
assert df_enc['patient_id'].notna().all()
assert df_cond['patient_id'].notna().all()

# %%
assert df_obs['patient_id'].isin(df_patients['patient_id']).all()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 assert df_obs['patient_id'].isin(df_patients['patient_id']).all()
#
# AssertionError:

# %%
invalid_obs = df_obs.loc[
    ~df_obs['patient_id'].isin(df_patients['patient_id'])
]
len(invalid_obs)
# Out:
# 585691

# %%
df_patients.shape, df_obs.shape
# Out:
# ((1159, 3), (585691, 6))

# %%
df_patients.columns, df_obs.columns
# Out:
# (Index(['patient_id', 'gender', 'birth_date'], dtype='object'),
#  Index(['patient_id', 'code', 'name', 'value', 'unit', 'time'], dtype='object'))

# %%
df_patients.head(), df_obs.head(), df_enc.head(), df_cond.head()
# Out:
# (                             patient_id  gender  birth_date
#  0  a8a4c7d6-722a-a914-04b6-a23a7c3496e2  female  1999-05-21
#  1  779b82f4-c8cd-9764-2f80-28f0b176a418  female  2000-03-03
#  2  e696153b-4bda-a741-04fe-a1fd43f60fd9  female  1972-04-14
#  3  7e0366e0-5cf1-1f51-f609-3ec9c2197140  female  1998-03-26
#  4  f286e228-2d19-4405-da1c-23dcae75169b  female  1971-04-03,
#                                        patient_id    code  \
#  0  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2  6206-7
#  1  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2  6273-7
#  2  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2  6082-2
#  3  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2  6246-3
#  4  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2  6276-0
#
#                                       name     value  unit  \
#  0   Peanut IgE Ab [Units/volume] in Serum  0.088943  kU/L
#  1   Walnut IgE Ab [Units/volume] in Serum  0.086704  kU/L
#  2  Codfish IgE Ab [Units/volume] in Serum  0.033234  kU/L
#  3   Shrimp IgE Ab [Units/volume] in Serum  0.298170  kU/L
#  4    Wheat IgE Ab [Units/volume] in Serum  0.151060  kU/L
#
#                          time
#  0  2016-06-26T10:58:45-04:00
#  1  2016-06-26T10:58:45-04:00
#  2  2016-06-26T10:58:45-04:00
#  3  2016-06-26T10:58:45-04:00
#  4  2016-06-26T10:58:45-04:00  ,
#                                        patient_id  \
#  0  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2
#  1  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2
#  2  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2
#  3  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2
#  4  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2
#
#                             encounter_id                      start  \
#  0  a8a4c7d6-722a-a914-08ad-b3487ef3841c  2002-07-05T05:10:07-04:00
#  1  a8a4c7d6-722a-a914-361b-7ce09b223ba3  2002-07-07T19:10:07-04:00
#  2  a8a4c7d6-722a-a914-336b-d22ae367ca4f  2012-05-25T05:10:07-04:00
#  3  a8a4c7d6-722a-a914-1914-d529e1eb8980  2013-02-15T04:10:07-05:00
#  4  a8a4c7d6-722a-a914-c010-05323bffc60e  2015-05-10T05:10:07-04:00
#
#                           end class
#  0  2002-07-05T05:25:07-04:00   AMB
#  1  2002-07-07T19:39:24-04:00   AMB
#  2  2012-05-25T05:31:15-04:00   AMB
#  3  2013-02-15T04:25:07-05:00   AMB
#  4  2015-05-10T05:25:07-04:00   AMB  ,
#                                        patient_id  \
#  0  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2
#  1  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2
#  2  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2
#  3  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2
#  4  urn:uuid:a8a4c7d6-722a-a914-04b6-a23a7c3496e2
#
#                             condition_id       code  \
#  0  a8a4c7d6-722a-a914-557d-67cc3166d819  367498001
#  1  a8a4c7d6-722a-a914-4b62-c14a12b6feb2  314529007
#  2  a8a4c7d6-722a-a914-3821-c283230cd572   72892002
#  3  a8a4c7d6-722a-a914-2448-0d44be79cfdc  224299000
#  4  a8a4c7d6-722a-a914-fbce-2c51d5add2eb  160903007
#
#                                      name                      onset  \
#  0  Seasonal allergic rhinitis (disorder)  2002-07-05T05:10:07-04:00
#  1      Medication review due (situation)  2013-02-15T04:10:07-05:00
#  2             Normal pregnancy (finding)  2016-10-07T05:10:07-04:00
#  3    Received higher education (finding)  2017-06-23T05:47:57-04:00
#  4         Full-time employment (finding)  2017-06-23T05:47:57-04:00
#
#                 recorded_date clinical_status  is_prediabetes  is_diabetes
#  0  2002-07-05T05:10:07-04:00        resolved           False        False
#  1  2013-02-15T04:10:07-05:00        resolved           False        False
#  2  2016-10-07T05:10:07-04:00        resolved           False        False
#  3  2017-06-23T05:47:57-04:00          active           False        False
#  4  2017-06-23T05:47:57-04:00        resolved           False        False  )

# %%
# helper function to format patient_id in all dataframes exactly as seen in df_patients

def strip_urn_uuid(x):
    """remove urn:uuid: prefix from patient_id
    from all dataframes
    """
    
    if pd.isna(x):
        return None
    x = str(x)
    return x.replace("urn:uuid:", "")

# %%
# modify patient_id format in all dataframes to match patient_id in df_patients

for df in [df_obs, df_enc, df_cond]:
    df['patient_id'] = df['patient_id'].apply(strip_urn_uuid)

# %%
# validate all patient_ids actoss all dataframes match with those in df_patients

assert df_obs['patient_id'].isin(df_patients['patient_id']).all()
assert df_enc['patient_id'].isin(df_patients['patient_id']).all()
assert df_cond['patient_id'].isin(df_patients['patient_id']).all()

# %% [markdown]
# #### Data Types and Conversions

# %%
# df_obs time column converted to datetime

df_obs['time'] = pd.to_datetime(df_obs['time'], utc=True)
df_obs.dtypes
# Out:
# patient_id                 object
# code                       object
# name                       object
# value                     float64
# unit                       object
# time          datetime64[ns, UTC]
# dtype: object

# %%
for col in ['start','end']:
    df_enc[col] = pd.to_datetime(df_enc[col], utc=True)
df_enc.dtypes
# Out:
# patient_id                   object
# encounter_id                 object
# start           datetime64[ns, UTC]
# end             datetime64[ns, UTC]
# class                        object
# dtype: object

# %%
for col in ['onset', 'recorded_date']:
    df_cond[col] = pd.to_datetime(df_cond[col], utc=True)
df_cond.dtypes
# Out:
# patient_id                      object
# condition_id                    object
# code                             int64
# name                            object
# onset              datetime64[ns, UTC]
# recorded_date      datetime64[ns, UTC]
# clinical_status                 object
# is_prediabetes                    bool
# is_diabetes                       bool
# dtype: object

# %% [markdown]
# #### Missing Data

# %%
df_obs.isna().mean().sort_values(ascending=False)
# Out:
# value         0.22237
# unit          0.22237
# patient_id    0.00000
# code          0.00000
# name          0.00000
# time          0.00000
# dtype: float64

# %%
(
    df_obs[df_obs['value'].isna()]
    .groupby('name')
    .size()
    .sort_values(ascending=False)
    .head(15)
)
# Out:
# name
# Blood pressure panel with all children optional                                                16430
# Tobacco smoking status                                                                         14815
# Protocol for Responding to and Assessing Patients' Assets, Risks, and Experiences [PRAPARE]    11322
# Ketones [Presence] in Urine by Test strip                                                       7262
# Nitrite [Presence] in Urine by Test strip                                                       7262
# Hemoglobin [Presence] in Urine by Test strip                                                    7262
# Leukocyte esterase [Presence] in Urine by Test strip                                            7262
# Appearance of Urine                                                                             7142
# Color of Urine                                                                                  7091
# Glucose [Presence] in Urine by Test strip                                                       7091
# Protein [Presence] in Urine by Test strip                                                       7091
# Bilirubin.total [Presence] in Urine by Test strip                                               7091
# Clarity of Urine                                                                                7091
# Odor of Urine                                                                                   7040
# Fall risk level [Morse Fall Scale]                                                              2997
# dtype: int64

# %%
#filter rows with numeric data only

df_obs_numeric = df_obs.loc[df_obs['value'].notna() & df_obs['unit'].notna()]
df_obs_numeric.isna().mean()
# Out:
# patient_id    0.0
# code          0.0
# name          0.0
# value         0.0
# unit          0.0
# time          0.0
# dtype: float64

# %%
df_enc.isna().mean().sort_values(ascending=False)
# Out:
# patient_id      0.0
# encounter_id    0.0
# start           0.0
# end             0.0
# class           0.0
# dtype: float64

# %%
df_cond.isna().mean().sort_values(ascending=False)
# Out:
# patient_id         0.0
# condition_id       0.0
# code               0.0
# name               0.0
# onset              0.0
# recorded_date      0.0
# clinical_status    0.0
# is_prediabetes     0.0
# is_diabetes        0.0
# dtype: float64

# %%
# Helper function to find duplicate rows

def find_duplicates(dfs: dict):
    for name, df in dfs.items():
        print(name)
        print(f"Duplicates Count: {df.duplicated().sum()}")

# %%
# find duplciates

dfs_updated =  {
    "Patients": df_patients,
    "Observations Numeric": df_obs_numeric,
    "Encounters": df_enc,
    "Conditions": df_cond
}
find_duplicates(dfs_updated)
# Out:
# Patients
# Duplicates Count: 0
# Observations Numeric
# Duplicates Count: 234
# Encounters
# Duplicates Count: 0
# Conditions
# Duplicates Count: 0

# %%
# inspect observations df for duplicates

subset_cols = ['patient_id','code','time']
print(f"Duplicate observations count: {df_obs_numeric.duplicated(subset=subset_cols,keep=False).sum()}")
# Out:
# Duplicate observations count: 4420

# %%
# deduplicate observation df based on subset columns

deduped = df_obs_numeric.drop_duplicates(subset=subset_cols)
deduped.duplicated().sum()
# Out:
# 0

# %%
# assign deduplicated df back to numeric observation df
df_obs_numeric = deduped

# %%
# rerun duplicates check after cleaning

find_duplicates(dfs_updated)
# Out:
# Patients
# Duplicates Count: 0
# Observations Numeric
# Duplicates Count: 234
# Encounters
# Duplicates Count: 0
# Conditions
# Duplicates Count: 0

# %%
# validate deduplication

# dictionary of deduplicated dataframes
dfs_deduped =  {
    "Patients": df_patients,
    "Observations Numeric": df_obs_numeric,
    "Encounters": df_enc,
    "Conditions": df_cond
}

find_duplicates(dfs_deduped)
# Out:
# Patients
# Duplicates Count: 0
# Observations Numeric
# Duplicates Count: 0
# Encounters
# Duplicates Count: 0
# Conditions
# Duplicates Count: 0

# %% [markdown]
# #### Semantic Checks

# %%
# check for kinds of labs present in observations df
# ideally want vitals, HbA1c, BMI, random glucose, BUN/Cr, filtration rates

df_obs_numeric['name'].value_counts().head(30)
# Out:
# name
# Pain severity - 0-10 verbal numeric rating [Score] - Reported                                                    25379
# Body Weight                                                                                                      15624
# Respiratory rate                                                                                                 15239
# Heart rate                                                                                                       15239
# Body Height                                                                                                      14857
# Body mass index (BMI) [Ratio]                                                                                    13773
# Sodium [Moles/volume] in Blood                                                                                   10015
# Creatinine [Mass/volume] in Blood                                                                                10015
# Glucose [Mass/volume] in Blood                                                                                   10015
# Potassium [Moles/volume] in Blood                                                                                10015
# Chloride [Moles/volume] in Blood                                                                                 10015
# Carbon dioxide, total [Moles/volume] in Blood                                                                    10015
# Calcium [Mass/volume] in Blood                                                                                   10015
# Glomerular filtration rate [Volume Rate/Area] in Serum or Plasma by Creatinine-based formula (MDRD)/1.73 sq M     9987
# Urea nitrogen [Mass/volume] in Blood                                                                              9733
# Hemoglobin A1c/Hemoglobin.total in Blood                                                                          9017
# Weight difference [Mass difference] --pre dialysis - post dialysis                                                8887
# Patient Health Questionnaire 2 item (PHQ-2) total score [Reported]                                                8665
# pH of Urine by Test strip                                                                                         7419
# Specific gravity of Urine by Test strip                                                                           7419
# Protein [Mass/volume] in Urine by Test strip                                                                      7262
# Glucose [Mass/volume] in Urine by Test strip                                                                      7262
# Bilirubin.total [Mass/volume] in Urine by Test strip                                                              7091
# Ketones [Mass/volume] in Urine by Test strip                                                                      7091
# Potassium [Moles/volume] in Serum or Plasma                                                                       6591
# Urea nitrogen [Mass/volume] in Serum or Plasma                                                                    6591
# Chloride [Moles/volume] in Serum or Plasma                                                                        6591
# Carbon dioxide, total [Moles/volume] in Serum or Plasma                                                           6591
# Creatinine [Mass/volume] in Serum or Plasma                                                                       6591
# Calcium [Mass/volume] in Serum or Plasma                                                                          6591
# Name: count, dtype: int64

# %%
# conditions
df_cond[(df_cond['is_prediabetes'] & df_cond['is_diabetes'])].head(10)
# Out:
#                                 patient_id  \
# 10    a8a4c7d6-722a-a914-04b6-a23a7c3496e2
# 92    7e0366e0-5cf1-1f51-f609-3ec9c2197140
# 225   b75f55d6-a56b-611e-228a-8b5c87031609
# 347   7959479b-5d1e-a9b6-bf6c-d09240490c0e
# 383   dbc13ff9-face-3a16-b7b2-0073d73dea9a
# 665   3e5092da-7854-5cfe-2cfb-8f3c96e182fd
# 840   5025c250-3ac9-baa5-dd1e-62dbf6f69c2c
# 971   ff814ec6-8d8e-5389-f58e-15468c445d70
# 1028  d6762ace-3c39-629e-42b7-de52c101adee
# 1065  96523502-dee5-a97b-e441-7d040dec38bc
#
#                               condition_id       code                   name  \
# 10    a8a4c7d6-722a-a914-fd83-023b0a892baf  714628002  Prediabetes (finding)
# 92    7e0366e0-5cf1-1f51-fe6b-d07139361ab5  714628002  Prediabetes (finding)
# 225   b75f55d6-a56b-611e-5664-0f12f2d3f2cd  714628002  Prediabetes (finding)
# 347   7959479b-5d1e-a9b6-0d44-1a4b89748b44  714628002  Prediabetes (finding)
# 383   dbc13ff9-face-3a16-3595-9b1b323e77e9  714628002  Prediabetes (finding)
# 665   3e5092da-7854-5cfe-4033-d2939757e402  714628002  Prediabetes (finding)
# 840   5025c250-3ac9-baa5-820c-5744fd6437d2  714628002  Prediabetes (finding)
# 971   ff814ec6-8d8e-5389-61a2-7fac0b4593d8  714628002  Prediabetes (finding)
# 1028  d6762ace-3c39-629e-0c45-c9e901aea578  714628002  Prediabetes (finding)
# 1065  96523502-dee5-a97b-9285-aa381c44044e  714628002  Prediabetes (finding)
#
#                          onset             recorded_date clinical_status  \
# 10   2018-07-20 09:10:07+00:00 2018-07-20 09:10:07+00:00          active
# 92   2020-05-29 04:33:52+00:00 2020-05-29 04:33:52+00:00          active
# 225  2011-12-02 20:47:36+00:00 2011-12-02 20:47:36+00:00          active
# 347  2025-04-29 07:15:40+00:00 2025-04-29 07:15:40+00:00          active
# 383  1987-02-27 17:12:34+00:00 1987-02-27 17:12:34+00:00          active
# 665  1971-05-02 19:00:43+00:00 1971-05-02 19:00:43+00:00          active
# 840  2009-09-30 16:49:27+00:00 2009-09-30 16:49:27+00:00          active
# 971  1996-02-02 02:19:57+00:00 1996-02-02 02:19:57+00:00          active
# 1028 2007-09-01 08:11:02+00:00 2007-09-01 08:11:02+00:00          active
# 1065 1944-07-17 18:21:48+00:00 1944-07-17 18:21:48+00:00          active
#
#       is_prediabetes  is_diabetes
# 10              True         True
# 92              True         True
# 225             True         True
# 347             True         True
# 383             True         True
# 665             True         True
# 840             True         True
# 971             True         True
# 1028            True         True
# 1065            True         True

# %%
df_enc['class'].value_counts().head(10)
# Out:
# class
# AMB     61955
# EMER     2320
# IMP      1263
# HH        510
# VR        118
# Name: count, dtype: int64

# %% [markdown]
# #### Dates Conversion Validation

# %%
df_patients['birth_date'] = pd.to_datetime(df_patients['birth_date'], utc=True)

# %%
df_patients.dtypes, df_obs_numeric.dtypes, df_enc.dtypes, df_cond.dtypes
# Out:
# (patient_id                 object
#  gender                     object
#  birth_date    datetime64[ns, UTC]
#  dtype: object,
#  patient_id                 object
#  code                       object
#  name                       object
#  value                     float64
#  unit                       object
#  time          datetime64[ns, UTC]
#  dtype: object,
#  patient_id                   object
#  encounter_id                 object
#  start           datetime64[ns, UTC]
#  end             datetime64[ns, UTC]
#  class                        object
#  dtype: object,
#  patient_id                      object
#  condition_id                    object
#  code                             int64
#  name                            object
#  onset              datetime64[ns, UTC]
#  recorded_date      datetime64[ns, UTC]
#  clinical_status                 object
#  is_prediabetes                    bool
#  is_diabetes                       bool
#  dtype: object)

# %% [markdown]
# ## Cohort Segmentation for Modeling

# %% [markdown]
# #### Define Cohort
# ##### We are interested in the adult population so all patients must be 18 years or older.

# %%
df_patients.head(2)
# Out:
#                              patient_id  gender                birth_date
# 0  a8a4c7d6-722a-a914-04b6-a23a7c3496e2  female 1999-05-21 00:00:00+00:00
# 1  779b82f4-c8cd-9764-2f80-28f0b176a418  female 2000-03-03 00:00:00+00:00

# %%
# add age column for patients
reference_date = pd.Timestamp.now(tz='UTC')
df_patients['age'] = (reference_date - df_patients['birth_date']).dt.days // 365
df_patients.head()
# Out:
#                              patient_id  gender                birth_date  age
# 0  a8a4c7d6-722a-a914-04b6-a23a7c3496e2  female 1999-05-21 00:00:00+00:00   26
# 1  779b82f4-c8cd-9764-2f80-28f0b176a418  female 2000-03-03 00:00:00+00:00   25
# 2  e696153b-4bda-a741-04fe-a1fd43f60fd9  female 1972-04-14 00:00:00+00:00   53
# 3  7e0366e0-5cf1-1f51-f609-3ec9c2197140  female 1998-03-26 00:00:00+00:00   27
# 4  f286e228-2d19-4405-da1c-23dcae75169b  female 1971-04-03 00:00:00+00:00   54

# %%
# filter all patients >= 18 years

df_patients_adult = df_patients.loc[df_patients['age'] >= 18].copy()

# %%
# helper function to filter to adult patients
def filter_to_adult(df, adult_ids, id_col='patient_id'):
    """
    filter all patients in dataframe that are present in adult_ids
    """
    return df.loc[df[id_col].isin(adult_ids)].copy()

# %%
# filter all dataframes for adult patient only

adult_pt_ids = df_patients_adult['patient_id']

df_obs_adult = filter_to_adult(df_obs_numeric, adult_pt_ids)
df_enc_adult = filter_to_adult(df_enc, adult_pt_ids)
df_cond_adult = filter_to_adult(df_cond, adult_pt_ids)

# %%
# check dimensions after filtering

for df in [df_patients_adult,
          df_obs_adult,
          df_enc_adult,
          df_cond_adult]:
    print(df.shape)
# Out:
# (956, 4)
# (427494, 6)
# (61204, 5)
# (39093, 9)

# %% [markdown]
# ## Outcome: Diabetes onset
# ### Definition:
# #### First occurrence of Type 2 Diabetes diagnosis OR
# #### First occurrence of diabetes-related complication

# %% [markdown]
# ### Cases Cohort

# %%
# Cases cohort: all patients with diabetes
# filter first date of diabetes diagnosis

df_dm_events = df_cond_adult.loc[df_cond_adult['is_diabetes']].copy()
df_dm_onset = (
    df_dm_events
    .groupby('patient_id')['onset']
    .min()
    .reset_index()
    .rename(columns={'onset':'diabetes_onset_date'})
)

# %%
print(
    f"\nDiabetes Cases df Shape: {df_dm_onset.shape}\n"
    f"\nFirst few rows:\n"
    f"\n{df_dm_onset.head()}")
# Out:
# Diabetes Cases df Shape: (503, 2)
#
# First few rows:
#
#                              patient_id       diabetes_onset_date
# 0  00a22b4e-fa50-0dd1-ac9e-f91e8b7fc2b4 1947-10-13 04:52:13+00:00
# 1  00b05b83-aee7-281a-fe2b-b1151bd7c5ee 2009-07-06 14:56:01+00:00
# 2  011dcab7-8543-84f8-5842-fa84972bbf25 2020-02-07 17:52:29+00:00
# 3  016329fd-8f76-971e-d716-709f9f529dc7 1997-06-08 11:06:54+00:00
# 4  01fac8f1-8eac-04bb-1d5c-8dbead000d6c 2002-06-09 16:06:33+00:00

# %% [markdown]
# ### Controls Cohort

# %%
df_last_seen = (
    df_enc_adult
    .groupby('patient_id')['start']
    .max()
    .reset_index()
    .rename(columns={'start':'last_encounter_date'})
)

# %%
df_cohort = df_patients_adult[['patient_id']].copy()
df_cohort = df_cohort.merge(df_dm_onset, on='patient_id', how='left')
df_cohort = df_cohort.merge(df_last_seen, on='patient_id', how='left')

df_cohort.head()
# Out:
#                              patient_id       diabetes_onset_date  \
# 0  a8a4c7d6-722a-a914-04b6-a23a7c3496e2 2018-07-20 09:10:07+00:00
# 1  779b82f4-c8cd-9764-2f80-28f0b176a418                       NaT
# 2  e696153b-4bda-a741-04fe-a1fd43f60fd9                       NaT
# 3  7e0366e0-5cf1-1f51-f609-3ec9c2197140 2020-05-29 04:33:52+00:00
# 4  f286e228-2d19-4405-da1c-23dcae75169b 2021-05-29 14:35:55+00:00
#
#         last_encounter_date
# 0 2025-01-21 09:10:07+00:00
# 1 2025-05-24 03:32:57+00:00
# 2 2022-06-10 14:14:34+00:00
# 3 2025-10-31 04:33:52+00:00
# 4 2025-10-11 14:35:55+00:00

# %%
labels = df_cohort['diabetes_onset_date'].notna().astype(int)
labels.head(2)
# Out:
# 0    1
# 1    0
# Name: diabetes_onset_date, dtype: int64

# %%
# create labels column
df_cohort['label'] = labels

# index_date will be the date we predict from, either 1 year prior
# from dm diagnosis for dm patients or
# 1 year prior to last encounter date for patients
# who never develop dm

df_cohort['index_date'] = np.where(
    df_cohort['label'] == 1,
    df_cohort['diabetes_onset_date'] - pd.Timedelta(days=365),
    df_cohort['last_encounter_date'] - pd.Timedelta(days=365)
)

df_cohort.head()
# Out:
#                              patient_id       diabetes_onset_date  \
# 0  a8a4c7d6-722a-a914-04b6-a23a7c3496e2 2018-07-20 09:10:07+00:00
# 1  779b82f4-c8cd-9764-2f80-28f0b176a418                       NaT
# 2  e696153b-4bda-a741-04fe-a1fd43f60fd9                       NaT
# 3  7e0366e0-5cf1-1f51-f609-3ec9c2197140 2020-05-29 04:33:52+00:00
# 4  f286e228-2d19-4405-da1c-23dcae75169b 2021-05-29 14:35:55+00:00
#
#         last_encounter_date  label                index_date
# 0 2025-01-21 09:10:07+00:00      1 2017-07-20 09:10:07+00:00
# 1 2025-05-24 03:32:57+00:00      0 2024-05-24 03:32:57+00:00
# 2 2022-06-10 14:14:34+00:00      0 2021-06-10 14:14:34+00:00
# 3 2025-10-31 04:33:52+00:00      1 2019-05-30 04:33:52+00:00
# 4 2025-10-11 14:35:55+00:00      1 2020-05-29 14:35:55+00:00

# %%
# develop features dataframe
# merge observaitons df with cohort df on patient_id

df_obs_features = df_obs_adult.merge(
    df_cohort[['patient_id', 'index_date']],
    on='patient_id'
    )
df_obs_features.head()
# Out:
#                              patient_id    code  \
# 0  a8a4c7d6-722a-a914-04b6-a23a7c3496e2  6206-7
# 1  a8a4c7d6-722a-a914-04b6-a23a7c3496e2  6273-7
# 2  a8a4c7d6-722a-a914-04b6-a23a7c3496e2  6082-2
# 3  a8a4c7d6-722a-a914-04b6-a23a7c3496e2  6246-3
# 4  a8a4c7d6-722a-a914-04b6-a23a7c3496e2  6276-0
#
#                                      name     value  unit  \
# 0   Peanut IgE Ab [Units/volume] in Serum  0.088943  kU/L
# 1   Walnut IgE Ab [Units/volume] in Serum  0.086704  kU/L
# 2  Codfish IgE Ab [Units/volume] in Serum  0.033234  kU/L
# 3   Shrimp IgE Ab [Units/volume] in Serum  0.298170  kU/L
# 4    Wheat IgE Ab [Units/volume] in Serum  0.151060  kU/L
#
#                        time                index_date
# 0 2016-06-26 14:58:45+00:00 2017-07-20 09:10:07+00:00
# 1 2016-06-26 14:58:45+00:00 2017-07-20 09:10:07+00:00
# 2 2016-06-26 14:58:45+00:00 2017-07-20 09:10:07+00:00
# 3 2016-06-26 14:58:45+00:00 2017-07-20 09:10:07+00:00
# 4 2016-06-26 14:58:45+00:00 2017-07-20 09:10:07+00:00

# %%
# filter observations that are taken 1 year prior to the index_date for each patient
df_obs_features = df_obs_features[
    (df_obs_features['time'] < df_obs_features['index_date']) &
    (df_obs_features['time'] >= df_obs_features['index_date'] - pd.Timedelta(days=365))
]

# %%
df_obs_features.head()
# Out:
#                               patient_id     code  \
# 24  a8a4c7d6-722a-a914-04b6-a23a7c3496e2   8302-2
# 25  a8a4c7d6-722a-a914-04b6-a23a7c3496e2  72514-3
# 26  a8a4c7d6-722a-a914-04b6-a23a7c3496e2  29463-7
# 27  a8a4c7d6-722a-a914-04b6-a23a7c3496e2  39156-5
# 28  a8a4c7d6-722a-a914-04b6-a23a7c3496e2  59576-9
#
#                                                  name    value     unit  \
# 24                                        Body Height  155.800       cm
# 25  Pain severity - 0-10 verbal numeric rating [Sc...    1.000  {score}
# 26                                        Body Weight   56.300       kg
# 27                      Body mass index (BMI) [Ratio]   23.200    kg/m2
# 28  Body mass index (BMI) [Percentile] Per age and...   70.058        %
#
#                         time                index_date
# 24 2017-06-23 09:10:07+00:00 2017-07-20 09:10:07+00:00
# 25 2017-06-23 09:10:07+00:00 2017-07-20 09:10:07+00:00
# 26 2017-06-23 09:10:07+00:00 2017-07-20 09:10:07+00:00
# 27 2017-06-23 09:10:07+00:00 2017-07-20 09:10:07+00:00
# 28 2017-06-23 09:10:07+00:00 2017-07-20 09:10:07+00:00

# %%
# identify vounts of LOINC lab codes
df_obs_features[['code']].value_counts().head(20)
# Out:
# code
# 72514-3    630
# 29463-7    455
# 9279-1     436
# 8867-4     436
# 8302-2     428
# 39156-5    421
# 55758-7    291
# 70274-6    214
# 718-7      150
# 6690-2     147
# 777-3      147
# 786-4      147
# 787-2      147
# 788-0      147
# 789-8      147
# 785-6      147
# 2571-8     143
# 4544-3     143
# 2085-9     143
# 2093-3     143
# Name: count, dtype: int64

# %%
feature_codes = {
    '29463-7',   # weight
    '8302-2',    # height
    '39156-5',   # BMI
    '8867-4',    # heart rate
    '9279-1',    # respiratory rate
    '70274-6',   # MAP
    '2571-8',    # triglycerides
    '4544-3',    # HDL
    '2093-3',    # LDL
    '2085-9'     # total cholesterol
}

# %%
df_obs_features = df_obs_features[
    df_obs_features['code'].isin(feature_codes)
    ].copy()

# %%
df_obs_features.shape
# Out:
# (2962, 7)

# %%
df_obs_features.head()
# Out:
#                               patient_id     code  \
# 24  a8a4c7d6-722a-a914-04b6-a23a7c3496e2   8302-2
# 26  a8a4c7d6-722a-a914-04b6-a23a7c3496e2  29463-7
# 27  a8a4c7d6-722a-a914-04b6-a23a7c3496e2  39156-5
# 29  a8a4c7d6-722a-a914-04b6-a23a7c3496e2   8867-4
# 30  a8a4c7d6-722a-a914-04b6-a23a7c3496e2   9279-1
#
#                              name  value   unit                      time  \
# 24                    Body Height  155.8     cm 2017-06-23 09:10:07+00:00
# 26                    Body Weight   56.3     kg 2017-06-23 09:10:07+00:00
# 27  Body mass index (BMI) [Ratio]   23.2  kg/m2 2017-06-23 09:10:07+00:00
# 29                     Heart rate   73.0   /min 2017-06-23 09:10:07+00:00
# 30               Respiratory rate   12.0   /min 2017-06-23 09:10:07+00:00
#
#                   index_date
# 24 2017-07-20 09:10:07+00:00
# 26 2017-07-20 09:10:07+00:00
# 27 2017-07-20 09:10:07+00:00
# 29 2017-07-20 09:10:07+00:00
# 30 2017-07-20 09:10:07+00:00

# %%
df_obs_features.groupby('code')['patient_id'].nunique()
# Out:
# code
# 2085-9     113
# 2093-3     113
# 2571-8     113
# 29463-7    395
# 39156-5    393
# 4544-3      96
# 70274-6    209
# 8302-2     395
# 8867-4     396
# 9279-1     396
# Name: patient_id, dtype: int64

# %%
df_cohort.head()
# Out:
#                              patient_id       diabetes_onset_date  \
# 0  a8a4c7d6-722a-a914-04b6-a23a7c3496e2 2018-07-20 09:10:07+00:00
# 1  779b82f4-c8cd-9764-2f80-28f0b176a418                       NaT
# 2  e696153b-4bda-a741-04fe-a1fd43f60fd9                       NaT
# 3  7e0366e0-5cf1-1f51-f609-3ec9c2197140 2020-05-29 04:33:52+00:00
# 4  f286e228-2d19-4405-da1c-23dcae75169b 2021-05-29 14:35:55+00:00
#
#         last_encounter_date  label                index_date
# 0 2025-01-21 09:10:07+00:00      1 2017-07-20 09:10:07+00:00
# 1 2025-05-24 03:32:57+00:00      0 2024-05-24 03:32:57+00:00
# 2 2022-06-10 14:14:34+00:00      0 2021-06-10 14:14:34+00:00
# 3 2025-10-31 04:33:52+00:00      1 2019-05-30 04:33:52+00:00
# 4 2025-10-11 14:35:55+00:00      1 2020-05-29 14:35:55+00:00

# %%
# save df_cohort and df_obs_features to csv and transiiton to feature engineering
df_cohort.to_csv(
    '/Users/sanasiddiqui/Desktop/Current Desktop/Data Portfolio Projects/Diabetes_Onset_Prediction_FHIR/Data_Diabetes_Prediction/Cleaned/df_cohort.csv',
    index=False
),
df_obs_features.to_csv(
    '/Users/sanasiddiqui/Desktop/Current Desktop/Data Portfolio Projects/Diabetes_Onset_Prediction_FHIR/Data_Diabetes_Prediction/Cleaned/df_obs_features.csv',
    index=False
)
